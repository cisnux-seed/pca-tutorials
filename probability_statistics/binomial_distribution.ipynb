# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
def find_binomial_distributions(n, p, x_title = ""):
    pmf = np.zeros(n + 1)
    x = np.arange(n + 1)
    for i in range(n + 1):
        coeffecient = math.factorial(n) / (math.factorial(i) * math.factorial(n - i))
        pmf[i] = coeffecient * (p**i) * ((1 - p) ** (n - i))
    _, ax = plt.subplots()
    ax.bar(x, pmf)
    ax.set_xlabel(x_title)
    ax.set_ylabel('probability distribution')
    plt.show()
    return pmf

# %%
# unbiased coin to find number of heads in 5 coins tosses
print(f"pmf of coin = {find_binomial_distributions(n=5, p=0.5, x_title='number of heads')}")
# Out:
# pmf of coin = [0.03125 0.15625 0.3125  0.3125  0.15625 0.03125]

# %%
# unbiased dices to find number of times we obtain the number 1
print(f"pmf of dices = {find_binomial_distributions(n=10, p=1/6, x_title='number of times the dice got 1')}")
# Out:
# pmf of dices = [1.61505583e-01 3.23011166e-01 2.90710049e-01 1.55045360e-01
#  5.42658759e-02 1.30238102e-02 2.17063503e-03 2.48072575e-04
#  1.86054431e-05 8.26908584e-07 1.65381717e-08]

# %%
# unbiased dices to find number of heads in 5 coins tosses
print(f"pmf of dices = {find_binomial_distributions(n=5, p=1/6, x_title='number of times the dice got 1')}")
# Out:
# pmf of dices = [4.01877572e-01 4.01877572e-01 1.60751029e-01 3.21502058e-02
#  3.21502058e-03 1.28600823e-04]

# %%
# biased coin to find number of heads in 5 coins tosses
print(f"pmf of coin = {find_binomial_distributions(n=5, p=0.3, x_title='number of heads')}")
# Out:
# pmf of coin = [0.16807 0.36015 0.3087  0.1323  0.02835 0.00243]
