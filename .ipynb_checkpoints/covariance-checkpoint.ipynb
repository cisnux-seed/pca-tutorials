# %% [markdown]
# ![1.png](attachment:8b5a7631-5c00-4463-9500-1668d18cdbe7.png)

# %%
import numpy as np

# %%
data = np.array([[1,2],[5,4],[-2,-3],[4,-2],[2,3],[8,-9]])
# np.mean(data,axis=0)
np.var(data,axis=0)
# Out:
# array([10.        , 19.80555556])
